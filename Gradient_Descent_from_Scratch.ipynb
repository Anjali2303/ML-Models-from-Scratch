# %%
# This function will take an array of weights as input.
# And return the computed value of the function as output
# The function written below is the function we have taken up to perform
# Gradient descent on.

def F(w):
  return 3*w[0]**2 + 4*w[1]**2 - 5*w[0] + 7

# %% [markdown]
# The [0] * x creates a list with x elements with all values as Zero.

# %%
def grad(w):
  g = [0]*2
  g[0] = 6*w[0] - 5
  g[1] = 8*w[1]
  return g

# %%
def descent(w_new,w_prev, lr):

  # lr is our learning rate
  print(w_prev)
  print(F(w_prev))
  while True:
    w_prev = w_new
    w_0 = w_prev[0] - lr*grad(w_prev)[0]
    w_1 = w_prev[1] - lr*grad(w_prev)[1]
    w_new = [w_0, w_1]
    print(w_new)
    print(F(w_new))

    if ((w_new[0]-w_prev[0])**2 + (w_new[1]-w_prev[1])**2) < pow(10,-7):
      break

# %%
descent([7,9],[7,9],0.02)
# Out:
# [7, 9]
# 443
# [6.26, 7.5600000000000005]
# 321.87719999999996
# [5.6088, 6.3504000000000005]
# 234.64223296
# [5.035743999999999, 5.334336]
# 171.717995144192
# [4.531454719999999, 4.48084224]
# 126.25676075730371
# [4.087680153599999, 3.7639074816000004]
# 93.35698446658377
# [3.697158535167999, 3.1616822845440002]
# 69.50609050025423
# [3.3534995109478394, 2.65581311901696]
# 52.183752647613375
# [3.0510795696340987, 2.2308830199742467]
# 39.57921796778295
# [2.7849500212780067, 1.873941736778367]
# 30.389720288018765
# [2.550756018724646, 1.5741110588938283]
# 23.676591210484187
# [2.3446652964776886, 1.3222532894708157]
# 18.76245462119755
# [2.163305460900366, 1.1106927631554853]
# 15.157697903486072
# [2.0037088055923222, 0.9329819210506076]
# 12.507823964892149
# [1.8632637489212436, 0.7837048136825104]
# 10.555709589482479
# [1.7396720990506944, 0.6583120434933087]
# 9.11451552782622
# [1.6309114471646111, 0.5529821165343793]
# 8.048216094482012
# ...
